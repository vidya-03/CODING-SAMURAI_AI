# %% [raw]
#                                        Artificial Intelligence Internship
# Author: Vidyashree
# Batch:Batch IND-1
# Email:vidyashree581110@gmail.com
# Domain:AI
# Task:Task 1
#
# Exploring the dataset
#
#                           Sentiment Analysis Of Movie Reviews

# %%
import pandas as pd #pandas for dataframe
import matplotlib.pyplot as plt #matplotlib for plotting

# %%
import sys #for increasing recursion limit
sys.setrecursionlimit(1000000)

# %%
df=pd.read_excel('IMDB Dataset.xlsx')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.groupby(by='sentiment',axis=0,sort=False).count()
# Out:
#            review
# sentiment
# positive    25000
# negative    24998

# %%
pos=df[df['sentiment']=='positive']

# %%
pos.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# 5  Probably my all-time favorite movie, a story o...  positive

# %%
pos.iloc[0,0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the fact that it goes where other shows wouldn't dare. Forget pretty pictures painted for mainstream audiences, forget charm, forget romance...OZ doesn't mess around. The first episode I ever saw struck me as so nasty it was surreal, I couldn't say I was ready for it, but as I watched more, I developed a taste for Oz, and got accustomed to the high levels of graphic violence. Not just violence, but injustice (crooked guards who'll be sold out for a nickel, inmates who'll kill on order and get away with it, well mannered, middle class inmates being turned into prison bitches due to their lack of street skills or prison experience) Watching Oz, you may become comfortable with what is uncomfortable viewing....thats if you can get in touch with your darker side."

# %%
neg=df[df['sentiment']=='negative']

# %%
neg.head()
# Out:
#                                                review sentiment
# 3   Basically there's a family where a little boy ...  negative
# 7   This show was an amazing, fresh & innovative i...  negative
# 8   Encouraged by the positive comments about this...  negative
# 10  Phil the Alien is one of those quirky films wh...  negative
# 11  I saw this movie when I was about 12 when it c...  negative

# %%
neg.iloc[0,0]
# Out:
# "Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them."

# %%
import re

# %%
def cleanTxt(text):
    text = str(text)
    text = text.lower()
    text = re.sub(r'[;:!\\"()\[\]]',"", text)
    text = re.sub(r'(<br\s*/><br\s*/>)|(\-)|(\/)'," ", text)
    return text

# %%
cleanTxt("Basically there's a family where a little boy (Jake) thinks there's a zombie in his closet & his parents are fighting all the time.<br /><br />This movie is slower than a soap opera... and suddenly, Jake decides to become Rambo and kill the zombie.<br /><br />OK, first of all when you're going to make a film you must Decide if its a thriller or a drama! As a drama the movie is watchable. Parents are divorcing & arguing like in real life. And then we have Jake with his closet which totally ruins all the film! I expected to see a BOOGEYMAN similar movie, and instead i watched a drama with some meaningless thriller spots.<br /><br />3 out of 10 just for the well playing parents & descent dialogs. As for the shots with Jake: just ignore them.")
# Out:
# "basically there's a family where a little boy jake thinks there's a zombie in his closet & his parents are fighting all the time. this movie is slower than a soap opera... and suddenly, jake decides to become rambo and kill the zombie. ok, first of all when you're going to make a film you must decide if its a thriller or a drama as a drama the movie is watchable. parents are divorcing & arguing like in real life. and then we have jake with his closet which totally ruins all the film i expected to see a boogeyman similar movie, and instead i watched a drama with some meaningless thriller spots. 3 out of 10 just for the well playing parents & descent dialogs. as for the shots with jake just ignore them."

# %%
df['review']=df['review'].apply(cleanTxt)

# %%
df
# Out:
#                                                   review sentiment
# 0      one of the other reviewers has mentioned that ...  positive
# 1      a wonderful little production.  the filming te...  positive
# 2      i thought this was a wonderful way to spend ti...  positive
# 3      basically there's a family where a little boy ...  negative
# 4      petter mattei's love in the time of money is a...  positive
# ...                                                  ...       ...
# 49995  i thought this movie did a down right good job...  positive
# 49996  bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  i am a catholic taught in parochial elementary...  negative
# 49998  i'm going to have to disagree with the previou...  negative
# 49999  no one expects the star trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
pos=df[df['sentiment']=='positive']

# %%
neg=df[df['sentiment']=='negative']

# %%
import nltk

# %%
word=nltk.word_tokenize(neg.iloc[0,0])
word
# Out:
# ['basically',
#  'there',
#  "'s",
#  'a',
#  'family',
#  'where',
#  'a',
#  'little',
#  'boy',
#  'jake',
#  'thinks',
#  'there',
#  "'s",
#  'a',
#  'zombie',
#  'in',
#  'his',
#  'closet',
#  '&',
#  'his',
#  'parents',
#  'are',
#  'fighting',
#  'all',
#  'the',
#  'time',
#  '.',
#  'this',
#  'movie',
#  'is',
#  'slower',
#  'than',
#  'a',
#  'soap',
#  'opera',
#  '...',
#  'and',
#  'suddenly',
#  ',',
#  'jake',
#  'decides',
#  'to',
#  'become',
#  'rambo',
#  'and',
#  'kill',
#  'the',
#  'zombie',
#  '.',
#  'ok',
#  ',',
#  'first',
#  'of',
#  'all',
#  'when',
#  'you',
#  "'re",
#  'going',
#  'to',
#  'make',
#  'a',
#  'film',
#  'you',
#  'must',
#  'decide',
#  'if',
#  'its',
#  'a',
#  'thriller',
#  'or',
#  'a',
#  'drama',
#  'as',
#  'a',
#  'drama',
#  'the',
#  'movie',
#  'is',
#  'watchable',
#  '.',
#  'parents',
#  'are',
#  'divorcing',
#  '&',
#  'arguing',
#  'like',
#  'in',
#  'real',
#  'life',
#  '.',
#  'and',
#  'then',
#  'we',
#  'have',
#  'jake',
#  'with',
#  'his',
#  'closet',
#  'which',
#  'totally',
#  'ruins',
#  'all',
#  'the',
#  'film',
#  'i',
#  'expected',
#  'to',
#  'see',
#  'a',
#  'boogeyman',
#  'similar',
#  'movie',
#  ',',
#  'and',
#  'instead',
#  'i',
#  'watched',
#  'a',
#  'drama',
#  'with',
#  'some',
#  'meaningless',
#  'thriller',
#  'spots',
#  '.',
#  '3',
#  'out',
#  'of',
#  '10',
#  'just',
#  'for',
#  'the',
#  'well',
#  'playing',
#  'parents',
#  '&',
#  'descent',
#  'dialogs',
#  '.',
#  'as',
#  'for',
#  'the',
#  'shots',
#  'with',
#  'jake',
#  'just',
#  'ignore',
#  'them',
#  '.']

# %%
sentence = nltk.sent_tokenize(pos.iloc[1,0])
sentence
# Out:
# ['a wonderful little production.',
#  'the filming technique is very unassuming  very old time bbc fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece.',
#  "the actors are extremely well chosen  michael sheen not only has got all the polari but he has all the voices down pat too you can truly see the seamless editing guided by the references to williams' diary entries, not only is it well worth the watching but it is a terrificly written and performed piece.",
#  "a masterful production about one of the great master's of comedy and his life.",
#  "the realism really comes home with the little things the fantasy of the guard which, rather than use the traditional 'dream' techniques remains solid then disappears.",
#  "it plays on our knowledge and our senses, particularly with the scenes concerning orton and halliwell and the sets particularly of their flat with halliwell's murals decorating every surface are terribly well done."]

# %%
def feature(sent):
    positive_words = ['wonderful','fun','good','excellent','terrific','masterful','outstanding','great','best','well','captivating',]
    negative_words = ['slower','bad','lengthy','worst','disgraceful','mediocrity','mediocre','horrible','terrible','pathetic','vague']
    count_neg = 0
    count_pos = 0
    word = nltk.word_tokenize(sent)
    for i in word:
        if i in positive_words:
            count_pos+=1
        if i in negative_words:
            count_neg+=1
#     try:
#         ratio=count_pos/count_neg
#     except:
#         ratio=count_pos+1
    feat={'positive_words':count_pos, 'negative_words':count_neg}
    return feat

# %%
feature(pos.iloc[1,0])
# Out:
# {'positive_words': 6, 'negative_words': 0}

# %%
featureset=df['review'].apply(feature)

# %%
featureset=featureset.to_list() #convert from object type to list

# %%
featureset
# Out:
# [{'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 2, 'negative_words': 9},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 7},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 3},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 4},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 5},
#  {'positive_words': 1, 'negative_words': 6},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 6},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 4},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 8, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 3},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 4},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 5},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 4},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 3},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 9, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 4},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 5},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 10, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 10, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 20, 'negative_words': 4},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 5},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 3},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 5},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 5},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 16, 'negative_words': 3},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 10, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 4},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 5},
#  {'positive_words': 6, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 7, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 5},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 4},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 9, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 7},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 5},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 6, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 4},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 8, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 8, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 4},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 5},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 9, 'negative_words': 3},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 9, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 7, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 9, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 8, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 6, 'negative_words': 2},
#  {'positive_words': 6, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 3},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 4},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 2},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 2},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 7, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 4},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 8, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 5},
#  {'positive_words': 3, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 5, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 3},
#  {'positive_words': 5, 'negative_words': 2},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 2},
#  {'positive_words': 0, 'negative_words': 1},
#  {'positive_words': 1, 'negative_words': 1},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 3, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 4, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 6, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 5},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  {'positive_words': 3, 'negative_words': 0},
#  {'positive_words': 1, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 0},
#  {'positive_words': 0, 'negative_words': 6},
#  {'positive_words': 2, 'negative_words': 0},
#  {'positive_words': 2, 'negative_words': 1},
#  ...]

# %%
featuredata=pd.DataFrame(featureset)

# %%
featuredata
# Out:
#        positive_words  negative_words
# 0                   1               0
# 1                   6               0
# 2                   3               0
# 3                   1               1
# 4                   3               0
# ...               ...             ...
# 49995               3               0
# 49996               0               4
# 49997               3               1
# 49998               0               0
# 49999               3               1
#
# [50000 rows x 2 columns]

# %%
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# importing necessary libraries 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split

# %%
X = np.array(featuredata.iloc[:,0:2]) #data(features)
y = np.array(df['sentiment']) #label

# %%
# dividing X, y into train and test data 
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25,random_state = 10)

# %%
# training a KNN classifier 
from sklearn.neighbors import KNeighborsClassifier 
knn = KNeighborsClassifier(n_neighbors = 7).fit(X_train, y_train)

# %%
# accuracy on X_test 
accuracy = knn.score(X_test, y_test) 
print(accuracy)
# Out:
# 0.69872

# %%
# creating a confusion matrix 
knn_predictions = knn.predict(X_test) 
cm = confusion_matrix(y_test, knn_predictions)

# %%
cm
# Out:
# array([[4276, 2080],
#        [1686, 4458]])

# %%
knn.predict(np.array([2,5]).reshape(1,2))
# Out:
# array(['negative'], dtype=object)

# %%
fig=plt.figure() #creating figure object 
axis=fig.add_axes([0,0,2,2])  #creating axis with custom dimensions
sns.scatterplot(x='positive_words',y='negative_words',data=featuredata,cmap='cmap_bold',hue=y,ax=axis)
